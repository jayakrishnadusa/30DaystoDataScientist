# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
y=df.Survived

# %%
X=df[['PassengerId','Pclass','Age','SibSp','Parch','Fare']]
X.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   183.000000  183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    1.191257   35.674426    0.464481    0.475410   78.682469
# std     247.052476    0.515187   15.643866    0.644159    0.754617   76.347843
# min       2.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%     263.500000    1.000000   24.000000    0.000000    0.000000   29.700000
# 50%     457.000000    1.000000   36.000000    0.000000    0.000000   57.000000
# 75%     676.000000    1.000000   47.500000    1.000000    1.000000   90.000000
# max     890.000000    3.000000   80.000000    3.000000    4.000000  512.329200

# %%
from sklearn.tree import DecisionTreeRegressor as tree

# %%
model=tree(random_state=0)

# %%
model.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
X.head()
# Out:
#     PassengerId  Pclass   Age  SibSp  Parch     Fare
# 1             2       1  38.0      1      0  71.2833
# 3             4       1  35.0      1      0  53.1000
# 6             7       1  54.0      0      0  51.8625
# 10           11       3   4.0      1      1  16.7000
# 11           12       1  58.0      0      0  26.5500

# %%
predictions=model.predict(X)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y,predictions)
# Out:
# 0.0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel=LogisticRegression(max_iter=1000)

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
predictions=logmodel.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,predictions)
# Out:
# 0.2786885245901639

# %%
pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    - -------------------------------------- 7.3/150.0 MB 45.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 19.4/150.0 MB 51.0 MB/s eta 0:00:03
#    -------- ------------------------------- 30.1/150.0 MB 51.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 40.9/150.0 MB 51.0 MB/s eta 0:00:03
#    ------------- -------------------------- 51.1/150.0 MB 50.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 64.7/150.0 MB 53.6 MB/s eta 0:00:02
#    ------------------- -------------------- 72.1/150.0 MB 51.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 84.7/150.0 MB 51.9 MB/s eta 0:00:02
#    -------------------------- ------------- 99.1/150.0 MB 54.5 MB/s eta 0:00:01
#    ---------------------------- ---------- 110.6/150.0 MB 54.3 MB/s eta 0:00:01
#    ------------------------------- ------- 120.6/150.0 MB 53.5 MB/s eta 0:00:01
# ...

# %%
from xgboost import  XGBClassifier as xgb

# %%
from sklearn.preprocessing import LabelEncoder

# %%
train_df=pd.read_csv('train.csv')
test_df=pd.read_csv('test.csv')

# %%
#Test passenger ids for later use
test_passenger_ids=test_df['PassengerId']

# %%
#using a df called combined_df to process together
combined_df=pd.concat([train_df.drop('Survived',axis=1),test_df],axis=0)

# %%
combined_df.isnull().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %% [markdown]
# ## Preprocessing

# %%
combined_df['Sex']=LabelEncoder().fit_transform(combined_df['Sex'])

# %%
combined_df['Embarked']=combined_df['Embarked'].fillna('S')
combined_df['Embarked']=LabelEncoder().fit_transform(combined_df['Embarked'])

# %% [markdown]
# #### Simple Imputer for Age and Fare missing values

# %%
from sklearn.impute import SimpleImputer

# %%
numimpute=SimpleImputer(strategy='median')

# %%
combined_df[['Age','Fare']]=numimpute.fit_transform(combined_df[['Age','Fare']])

# %% [markdown]
# ## Feature Selection

# %%
X=combined_df[['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]

# %%
X_train=X.iloc[:len(train_df)]
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         3    1  22.0      1      0   7.2500         2
# 1         1    0  38.0      1      0  71.2833         0
# 2         3    0  26.0      0      0   7.9250         2
# 3         1    0  35.0      1      0  53.1000         2
# 4         3    1  35.0      0      0   8.0500         2
# ..      ...  ...   ...    ...    ...      ...       ...
# 886       2    1  27.0      0      0  13.0000         2
# 887       1    0  19.0      0      0  30.0000         2
# 888       3    0  28.0      1      2  23.4500         2
# 889       1    1  26.0      0      0  30.0000         0
# 890       3    1  32.0      0      0   7.7500         1
#
# [891 rows x 7 columns]

# %%
X_test=X.iloc[len(train_df):]

# %%
y_train=train_df['Survived']

# %%
model=xgb(eval_metric='logloss')

# %%
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
predictions=model.predict(X_test)

# %%
submission=pd.DataFrame({
    'passengerId': test_passenger_ids,
    'Survived': predictions
})

# %%
submission.to_csv("submission.csv",index=False)
print("Submission.csv created successfully")
# Out:
# Submission.csv created successfully

# %%
submission.shape
# Out:
# (418, 2)
